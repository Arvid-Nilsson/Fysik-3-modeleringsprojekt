# %%
import numpy as np
import math
import matplotlib.pyplot as plt

# %%
# Mass of obeject
m = 5
# Spring constant
k = 10
#Gravitational acceleration
g = 9.82

#starting velocity
v0 = 20

#starting position
y0 = 0

#Steplength 
deltaT = 0.01

#Time of end of simulation
endT = 100

#Drag coeficient
r = 0.5

# %%
def calcForce(tempMass, tempG, tempK, tempY, tempR, tempV):
    """Function to calculate the force acting uppon the object"""
    return -tempMass*tempG - tempK *tempY - tempR * tempV

def calcAccel(tempF, tempMass):
    """Function to calculate the acceleration acting uppon the object"""
    return tempF / tempMass

# %%
#Creating arrays for time and position
timeArray = np.array([0])
positionArray = np.array([y0])

#Initializing the current values to starting values
y = y0 
v = v0
t = 0

while (t <= endT):

    #Calculate the acceleration
    a = calcAccel(calcForce(m,g,k,y,r,v),m)

    #Calculate the velocity
    v = v + a * deltaT

    #Calculate the position and saving it to array
    y = y + v * deltaT
    positionArray = np.append(positionArray, y)

    #Incrementing the time and adding it to the array
    t += deltaT
    timeArray = np.append(timeArray,t)

# %%
#Plotting the graphs
plt.plot(timeArray, positionArray)
plt.xlabel("time (s)")
plt.ylabel("y position (m)")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
